# %% [markdown]
# # Import Packages

# %%
import mysql.connector
from mysql.connector import errorcode
import config
import requests
import json
import pandas as pd
from urllib.request import urlopen
from json import loads

# %% [markdown]
# # Define Helper Functions

# %%
def get_educationdata(first_url):
    all_data = [] # container for data
    
    # Grab data from first url
    response = urlopen(first_url)
    data = loads(response.read())
    count = len(data['results'])
    all_data.append(data['results'])
    i = len(all_data)

    print('expecting ' + str(data['count']) + ' rows of data')
    
    # For following 'next' urls grab data, append to container
    while count < data['count']:
        if data['next'] is not None:
            try:
                response = urlopen(data['next'])
                data = loads(response.read())
                count += len(data['results'])
                all_data.append(data['results'])
                i += 1
                print('appended page ' + str(i))
                
            except:
                print('failed to append page ' + str(i))
    return all_data

# %%
def pages_to_one_df(data):
    data_dfs = []
    for page in range(0, len(data)):
        data_dfs.append(pd.DataFrame(data[page]))

    return pd.concat(data_dfs).reset_index(drop = True)

# %%
def data_to_tuples(data):
    data_tup = []
    for row in data.values:
        data_tup.append(tuple(row))
    return data_tup

# %%
def insert_data(data_tup, tbl_name, columns):
    
    # Connect to database
    cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.password,
    database = 'colleges',
    buffered = True
    )
    cursor = cnx.cursor()
    
    # Create insert statement
    len_col = len(columns)
    col_names = ', '.join(columns)
    num_col = '%s, '*len_col
    insert_statement = f"INSERT INTO {tbl_name} ({col_names}) VALUES ({num_col.strip(', ')})"
    print(insert_statement)
    
    # Execute insert statement for each tuple in list of data
    cursor.executemany(insert_statement, data_tup)
    cnx.commit()
    
    # Close connection
    cnx.close()
    return 'inserted data'

# %% [markdown]
# # Get Directory Info for Degree-Granting Institutions

# %%
url = "https://educationdata.urban.org/api/v1/college-university/ipeds/directory/2016"
ipeds_dir_data = get_educationdata(url)
ipeds_dir_df = pages_to_one_df(ipeds_dir_data)
# Out:
# expecting 7521 rows of data
# appended page 2
# appended page 3
# appended page 4
# appended page 5
# appended page 6
# appended page 7
# appended page 8

# %%
ipeds_dir_df.shape
# Out:
# (7521, 76)

# %%
ipeds_dir_columns = ['unitid', 'year', 'inst_name', 'state_abbr', 'region',
                     'urban_centric_locale', 'inst_status', 'currently_active_ipeds', 
                     'degree_granting', 'open_public', 'title_iv_indicator', 
                     'postsec_public_active', 'postsec_public_active_title_iv', 
                     'year_deleted', 'inst_control', 'institution_level', 'inst_category', 
                     'inst_size', 'sector', 'primarily_postsecondary', 'hbcu', 
                     'hospital', 'medical_degree', 'tribal_college', 'land_grant', 
                     'offering_highest_degree', 'offering_highest_level', 'offering_undergrad', 
                     'offering_grad', 'cc_basic_2015', 'cc_instruc_undergrad_2015', 
                     'cc_enroll_2015', 'cc_size_setting_2015']
ipeds_dir = ipeds_dir_df[ipeds_dir_columns]

# %%
ipeds_dir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7521 entries, 0 to 7520
# Data columns (total 33 columns):
# unitid                            7521 non-null int64
# year                              7521 non-null int64
# inst_name                         7521 non-null object
# state_abbr                        7521 non-null object
# region                            7521 non-null int64
# urban_centric_locale              7521 non-null int64
# inst_status                       7521 non-null object
# currently_active_ipeds            7521 non-null int64
# degree_granting                   7521 non-null int64
# open_public                       7521 non-null int64
# title_iv_indicator                7521 non-null int64
# postsec_public_active             7521 non-null int64
# postsec_public_active_title_iv    7521 non-null int64
# year_deleted                      7521 non-null int64
# inst_control                      7521 non-null int64
# institution_level                 7521 non-null int64
# inst_category                     7521 non-null int64
# inst_size                         7521 non-null int64
# sector                            7521 non-null int64
# primarily_postsecondary           7521 non-null int64
# hbcu                              7521 non-null int64
# hospital                          7521 non-null int64
# medical_degree                    7521 non-null int64
# tribal_college                    7521 non-null int64
# land_grant                        7521 non-null int64
# offering_highest_degree           7521 non-null int64
# offering_highest_level            7521 non-null int64
# offering_undergrad                7521 non-null int64
# offering_grad                     7521 non-null int64
# cc_basic_2015                     7521 non-null int64
# cc_instruc_undergrad_2015         7521 non-null int64
# cc_enroll_2015                    7521 non-null int64
# cc_size_setting_2015              7521 non-null int64
# dtypes: int64(30), object(3)
# memory usage: 1.9+ MB

# %%
ipeds_dir = ipeds_dir.astype({'inst_status': 'int64'})
ipeds_dir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7521 entries, 0 to 7520
# Data columns (total 33 columns):
# unitid                            7521 non-null int64
# year                              7521 non-null int64
# inst_name                         7521 non-null object
# state_abbr                        7521 non-null object
# region                            7521 non-null int64
# urban_centric_locale              7521 non-null int64
# inst_status                       7521 non-null int64
# currently_active_ipeds            7521 non-null int64
# degree_granting                   7521 non-null int64
# open_public                       7521 non-null int64
# title_iv_indicator                7521 non-null int64
# postsec_public_active             7521 non-null int64
# postsec_public_active_title_iv    7521 non-null int64
# year_deleted                      7521 non-null int64
# inst_control                      7521 non-null int64
# institution_level                 7521 non-null int64
# inst_category                     7521 non-null int64
# inst_size                         7521 non-null int64
# sector                            7521 non-null int64
# primarily_postsecondary           7521 non-null int64
# hbcu                              7521 non-null int64
# hospital                          7521 non-null int64
# medical_degree                    7521 non-null int64
# tribal_college                    7521 non-null int64
# land_grant                        7521 non-null int64
# offering_highest_degree           7521 non-null int64
# offering_highest_level            7521 non-null int64
# offering_undergrad                7521 non-null int64
# offering_grad                     7521 non-null int64
# cc_basic_2015                     7521 non-null int64
# cc_instruc_undergrad_2015         7521 non-null int64
# cc_enroll_2015                    7521 non-null int64
# cc_size_setting_2015              7521 non-null int64
# dtypes: int64(31), object(2)
# memory usage: 1.9+ MB

# %%
ipeds_dir.inst_status.value_counts() # 1 = active institution
ipeds_dir = ipeds_dir[ipeds_dir['inst_status'] == 1]

# %%
ipeds_dir = ipeds_dir[ipeds_dir['offering_undergrad'] == 1]
ipeds_dir = ipeds_dir[ipeds_dir['degree_granting'] == 1]

# %%
ipeds_dir.region.value_counts()
# Out:
# 5    1124
# 2     661
# 8     620
# 3     616
# 6     446
# 4     435
# 1     241
# 7     161
# 9      99
# 0       5
# Name: region, dtype: int64

# %% [markdown]
# ## Insert into MySQL Table

# %%
ipeds_dir_tuple = data_to_tuples(ipeds_dir)
insert_data(ipeds_dir_tuple, 'ipeds_dir', ipeds_dir_columns)
# Out:
# INSERT INTO ipeds_dir (unitid, year, inst_name, state_abbr, region, urban_centric_locale, inst_status, currently_active_ipeds, degree_granting, open_public, title_iv_indicator, postsec_public_active, postsec_public_active_title_iv, year_deleted, inst_control, institution_level, inst_category, inst_size, sector, primarily_postsecondary, hbcu, hospital, medical_degree, tribal_college, land_grant, offering_highest_degree, offering_highest_level, offering_undergrad, offering_grad, cc_basic_2015, cc_instruc_undergrad_2015, cc_enroll_2015, cc_size_setting_2015) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# 'inserted data'

# %% [markdown]
# # Get Institutional Characteristics

# %%
url = "https://educationdata.urban.org/api/v1/college-university/ipeds/institutional-characteristics/2016/"
ipeds_inst_char = get_educationdata(url)
ipeds_inst_char_df = pages_to_one_df(ipeds_inst_char)
# Out:
# expecting 7521 rows of data
# appended page 2
# appended page 3
# appended page 4
# appended page 5
# appended page 6
# appended page 7
# appended page 8

# %%
ipeds_inst_char_columns = ['unitid', 'year', 'inst_affiliation', 'primary_public_control', 
                           'occupational_prog_offered', 'academic_prog_offered', 
                           'cont_prof_prog_offered', 'avocational_prog_offered', 
                           'remedial_prog_offered', 'secondary_prog_offered', 'assoc_offered', 
                           'bach_offered', 'postbac_cert_offered', 'masters_offered', 
                           'doctors_research_offered', 'doctors_professional_offered', 
                           'doctors_other_offered', 'enrolled_undergrad_fulltime', 
                           'remedial_services', 'academic_counseling', 'employment_services', 
                           'placement_services', 'oncampus_daycare', 'oncampus_housing', 
                           'oncampus_required', 'meal_plan', 'typical_room_charge', 
                           'typical_board_charge', 'room_board_charge', 'tuition_varies', 
                           'alt_tuition', 'religious_affiliation', 'ap_credit', 'rotc', 
                           'study_abroad', 'weekend_evening_college', 'disability_indicator', 
                           'yellow_ribbon_program', 'veteran_point_of_contact', 
                           'student_veteran_organization', 'no_vet_services', 'library_physical', 
                           'library_digital', 'library_trained_staff', 'library_shared', 
                           'no_library', 'calendar_system']
ipeds_inst_char = ipeds_inst_char_df[ipeds_inst_char_columns]

# %%
# Replace nan values with None
# Check if in directory
ipeds_inst_char = ipeds_inst_char.where((pd.notnull(ipeds_inst_char)), None)
ipeds_inst_char = ipeds_inst_char[ipeds_inst_char['unitid'].isin(ipeds_dir['unitid'])]

# %%
ipeds_inst_char.info() # looks like ~200 data points may be missing most data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4408 entries, 0 to 7339
# Data columns (total 47 columns):
# unitid                          4408 non-null int64
# year                            4408 non-null int64
# inst_affiliation                4261 non-null object
# primary_public_control          4261 non-null object
# occupational_prog_offered       4261 non-null object
# academic_prog_offered           4261 non-null object
# cont_prof_prog_offered          4261 non-null object
# avocational_prog_offered        4261 non-null object
# remedial_prog_offered           4261 non-null object
# secondary_prog_offered          4261 non-null object
# assoc_offered                   4261 non-null object
# bach_offered                    4261 non-null object
# postbac_cert_offered            4261 non-null object
# masters_offered                 4261 non-null object
# doctors_research_offered        4261 non-null object
# doctors_professional_offered    4261 non-null object
# doctors_other_offered           4261 non-null object
# enrolled_undergrad_fulltime     4261 non-null object
# remedial_services               4261 non-null object
# academic_counseling             4261 non-null object
# employment_services             4261 non-null object
# placement_services              4261 non-null object
# oncampus_daycare                4261 non-null object
# oncampus_housing                4261 non-null object
# oncampus_required               4261 non-null object
# meal_plan                       4261 non-null object
# typical_room_charge             1606 non-null object
# typical_board_charge            1434 non-null object
# room_board_charge               407 non-null object
# tuition_varies                  4261 non-null object
# alt_tuition                     4261 non-null object
# religious_affiliation           4261 non-null object
# ap_credit                       4261 non-null object
# rotc                            4261 non-null object
# study_abroad                    4261 non-null object
# weekend_evening_college         4261 non-null object
# disability_indicator            4261 non-null object
# yellow_ribbon_program           4261 non-null object
# veteran_point_of_contact        4261 non-null object
# student_veteran_organization    4261 non-null object
# no_vet_services                 4261 non-null object
# library_physical                4261 non-null object
# library_digital                 4261 non-null object
# library_trained_staff           4261 non-null object
# library_shared                  4261 non-null object
# no_library                      4261 non-null object
# calendar_system                 4261 non-null object
# dtypes: int64(2), object(45)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Insert into MySql Table

# %%
ipeds_inst_char_tuple = data_to_tuples(ipeds_inst_char)
insert_data(ipeds_inst_char_tuple, 'ipeds_inst_char', ipeds_inst_char_columns)
# Out:
# INSERT INTO ipeds_inst_char (unitid, year, inst_affiliation, primary_public_control, occupational_prog_offered, academic_prog_offered, cont_prof_prog_offered, avocational_prog_offered, remedial_prog_offered, secondary_prog_offered, assoc_offered, bach_offered, postbac_cert_offered, masters_offered, doctors_research_offered, doctors_professional_offered, doctors_other_offered, enrolled_undergrad_fulltime, remedial_services, academic_counseling, employment_services, placement_services, oncampus_daycare, oncampus_housing, oncampus_required, meal_plan, typical_room_charge, typical_board_charge, room_board_charge, tuition_varies, alt_tuition, religious_affiliation, ap_credit, rotc, study_abroad, weekend_evening_college, disability_indicator, yellow_ribbon_program, veteran_point_of_contact, student_veteran_organization, no_vet_services, library_physical, library_digital, library_trained_staff, library_shared, no_library, calendar_system) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# 'inserted data'

# %% [markdown]
# # Get Enrollment Data

# %%
url = "https://educationdata.urban.org/api/v1/college-university/ipeds/admissions-enrollment/2016/"
ipeds_adm_enroll = get_educationdata(url)
ipeds_adm_enroll_df = pages_to_one_df(ipeds_adm_enroll)
# Out:
# expecting 22563 rows of data
# appended page 2
# appended page 3
# appended page 4
# appended page 5
# appended page 6
# appended page 7
# appended page 8
# appended page 9
# appended page 10
# appended page 11
# appended page 12
# appended page 13
# appended page 14
# appended page 15
# appended page 16
# appended page 17
# appended page 18
# appended page 19
# appended page 20
# appended page 21
# appended page 22
# appended page 23

# %%
# Replace numerical sex var with string representation
ipeds_adm_enroll_df = ipeds_adm_enroll_df.drop(['fips', 'year'], axis = 1)
ipeds_adm_enroll_df = ipeds_adm_enroll_df.replace({'sex': {1: 'M', 2: 'F', 99: 'N'}})

# Pivot dataframe
ipeds_adm_enroll_piv = ipeds_adm_enroll_df.pivot(index = 'unitid', columns = 'sex')
ipeds_adm_enroll_piv.reset_index(inplace = True)
ipeds_adm_enroll_piv.columns = ['_'.join(col).strip('_') for col in ipeds_adm_enroll_piv.columns.values]

# %%
# Replace nan values with None
# Check if in directory
ipeds_adm_enroll_piv = ipeds_adm_enroll_piv.where((pd.notnull(ipeds_adm_enroll_piv)), None)
ipeds_adm_enroll_piv = ipeds_adm_enroll_piv[ipeds_adm_enroll_piv['unitid'].isin(ipeds_dir['unitid'])]

# %%
ipeds_adm_enroll_piv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4408 entries, 0 to 7339
# Data columns (total 16 columns):
# unitid                     4408 non-null int64
# number_admitted_F          1833 non-null object
# number_admitted_M          1849 non-null object
# number_admitted_N          1897 non-null object
# number_applied_F           1906 non-null object
# number_applied_M           1906 non-null object
# number_applied_N           1907 non-null object
# number_enrolled_ft_F       1822 non-null object
# number_enrolled_ft_M       1832 non-null object
# number_enrolled_ft_N       1892 non-null object
# number_enrolled_pt_F       1479 non-null object
# number_enrolled_pt_M       1444 non-null object
# number_enrolled_pt_N       1490 non-null object
# number_enrolled_total_F    1830 non-null object
# number_enrolled_total_M    1840 non-null object
# number_enrolled_total_N    1895 non-null object
# dtypes: int64(1), object(15)
# memory usage: 585.4+ KB

# %% [markdown]
# ## Insert into MySQL Table

# %%
ipeds_adm_enroll_tuple = data_to_tuples(ipeds_adm_enroll_piv)
insert_data(ipeds_adm_enroll_tuple, 'ipeds_adm_enroll', ipeds_adm_enroll_piv.columns)
# Out:
# INSERT INTO ipeds_adm_enroll (unitid, number_admitted_F, number_admitted_M, number_admitted_N, number_applied_F, number_applied_M, number_applied_N, number_enrolled_ft_F, number_enrolled_ft_M, number_enrolled_ft_N, number_enrolled_pt_F, number_enrolled_pt_M, number_enrolled_pt_N, number_enrolled_total_F, number_enrolled_total_M, number_enrolled_total_N) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# 'inserted data'

# %% [markdown]
# # Get Scorecard Student Characteristics

# %%
url = "https://educationdata.urban.org/api/v1/college-university/scorecard/student-characteristics/2016/aid-applicants/"
sc_stud_char = get_educationdata(url)
sc_stud_char_df = pages_to_one_df(sc_stud_char)
# Out:
# expecting 6976 rows of data
# appended page 2
# appended page 3
# appended page 4
# appended page 5
# appended page 6
# appended page 7

# %%
sc_stud_char_df.describe()
# Out:
#        count_family_income  count_family_income_dependent  \
# count          6976.000000                    6976.000000
# mean           3159.814220                    1230.813217
# std            7091.258552                    2442.708313
# min              -3.000000                      -3.000000
# 25%             184.000000                      55.000000
# 50%             771.000000                     391.000000
# 75%            2661.250000                    1345.250000
# max           61975.000000                   22902.000000
#
#        count_family_income_independent  count_parent_ed  \
# count                      6976.000000      6976.000000
# mean                       1922.176892      2622.659404
# std                        5849.503324      5873.126193
# min                          -3.000000        -3.000000
# 25%                          73.750000       144.000000
# 50%                         281.000000       650.500000
# 75%                        1129.750000      2180.250000
# max                       56938.000000     50030.000000
#
#        count_total_fafsa_applicants  count_valid_dep_status  \
# count                   6976.000000             6976.000000
# mean                    3159.814220             3159.814220
# std                     7091.258552             7091.258552
# min                       -3.000000               -3.000000
# 25%                      184.000000              184.000000
# 50%                      771.000000              771.000000
# 75%                     2661.250000             2661.250000
# max                    61975.000000            61975.000000
#
#        dependent_highincome1_pct  dependent_highincome2_pct  \
# count                6976.000000                6976.000000
# mean                   -2.129866                  -2.132989
# std                     1.399859                   1.403510
# min                    -3.000000                  -3.000000
# 25%                    -3.000000                  -3.000000
# 50%                    -3.000000                  -3.000000
# 75%                     0.043916                   0.038351
# max                     0.500000                   0.559146
#
#        dependent_highincome_pct  dependent_income_mean  ...  midincome1_pct  \
# count               1921.000000            6976.000000  ...     6976.000000
# mean                   0.254190           45254.752133  ...       -0.368712
# std                    0.147374           26352.561264  ...        1.173290
# min                    0.019750              -3.000000  ...       -3.000000
# 25%                    0.145604           27790.700000  ...        0.106136
# 50%                    0.218125           42391.250000  ...        0.145091
# 75%                    0.354872           60715.800000  ...        0.172916
# max                    0.694932          152069.000000  ...        0.434783
#
#        midincome2_pct  midincome_pct        opeid6  \
# count     6976.000000    5121.000000   6976.000000
# mean        -0.668607       0.273947  16546.096474
# std          1.356935       0.064493  14369.921477
# min         -3.000000       0.065241   1002.000000
# 25%         -3.000000       0.231626   3239.000000
# 50%          0.098183       0.281307  10542.000000
# 75%          0.141916       0.319785  26216.250000
# max          0.354839       0.612179  42580.000000
#
#        parents_highest_ed_high_school  parents_highest_ed_middle_school  \
# count                     6976.000000                       6976.000000
# mean                        -1.001577                         -1.006737
# std                          1.414871                          1.416679
# min                         -3.000000                         -3.000000
# 25%                         -3.000000                         -3.000000
# 50%                          0.000000                          0.000000
# 75%                          0.000000                          0.000000
# max                          0.000000                          0.000000
#
#        parents_highest_ed_postsecondary        unitid  veteran_pct    year
# count                       6976.000000  6.976000e+03  6976.000000  6976.0
# mean                          -0.399943  1.852134e+06    -1.851927  2016.0
# std                            1.019815  6.932749e+06     1.464363     0.0
# min                           -3.000000  1.006540e+05    -3.000000  2016.0
# 25%                            0.000000  1.741248e+05    -3.000000  2016.0
# 50%                            0.000000  2.290495e+05    -3.000000  2016.0
# 75%                            0.000000  4.495985e+05     0.008010  2016.0
# max                            0.000000  4.877820e+07     0.346939  2016.0
#
# [8 rows x 49 columns]

# %%
sc_stud_char_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6976 entries, 0 to 6975
# Data columns (total 51 columns):
# age_24orolder_pct                   0 non-null object
# count_family_income                 6976 non-null int64
# count_family_income_dependent       6976 non-null int64
# count_family_income_independent     6976 non-null int64
# count_parent_ed                     6976 non-null int64
# count_total_fafsa_applicants        6976 non-null int64
# count_valid_dep_status              6976 non-null int64
# dependent_highincome1_pct           6976 non-null float64
# dependent_highincome2_pct           6976 non-null float64
# dependent_highincome_pct            1921 non-null float64
# dependent_income_mean               6976 non-null float64
# dependent_lowincome_pct             6976 non-null float64
# dependent_midincome1_pct            6976 non-null float64
# dependent_midincome2_pct            6976 non-null float64
# dependent_midincome_pct             3263 non-null float64
# dependent_pct                       6976 non-null float64
# fafsa_sent_2ormore_pct              6976 non-null float64
# fafsa_sent_3ormore_pct              6976 non-null float64
# fafsa_sent_4ormore_pct              6976 non-null float64
# fafsa_sent_5ormore_pct              6976 non-null float64
# faminc_independents_mean            6976 non-null float64
# faminc_mean                         6976 non-null float64
# faminc_med                          6976 non-null float64
# female_pct                          6976 non-null float64
# fips                                6976 non-null int64
# first_gen_student_pct               6976 non-null float64
# highincome1_pct                     6976 non-null float64
# highincome2_pct                     6976 non-null float64
# highincome_pct                      4478 non-null float64
# independent_highincome1_pct         6976 non-null float64
# independent_highincome2_pct         6976 non-null float64
# independent_highincome_pct          1921 non-null float64
# independent_income_mean             6976 non-null float64
# independent_lowincome_pct           6976 non-null float64
# independent_midincome1_pct          6976 non-null float64
# independent_midincome2_pct          6976 non-null float64
# independent_midincome_pct           3263 non-null float64
# independent_pct                     6976 non-null float64
# lowincome_pct                       6976 non-null float64
# married_pct                         6976 non-null float64
# midincome1_pct                      6976 non-null float64
# midincome2_pct                      6976 non-null float64
# midincome_pct                       5121 non-null float64
# opeid                               6976 non-null object
# opeid6                              6976 non-null int64
# parents_highest_ed_high_school      6976 non-null int64
# parents_highest_ed_middle_school    6976 non-null int64
# parents_highest_ed_postsecondary    6976 non-null int64
# unitid                              6976 non-null int64
# veteran_pct                         6976 non-null float64
# year                                6976 non-null int64
# dtypes: float64(36), int64(13), object(2)
# memory usage: 2.7+ MB

# %%
sc_stud_char_df.columns
# Out:
# Index(['age_24orolder_pct', 'count_family_income',
#        'count_family_income_dependent', 'count_family_income_independent',
#        'count_parent_ed', 'count_total_fafsa_applicants',
#        'count_valid_dep_status', 'dependent_highincome1_pct',
#        'dependent_highincome2_pct', 'dependent_highincome_pct',
#        'dependent_income_mean', 'dependent_lowincome_pct',
#        'dependent_midincome1_pct', 'dependent_midincome2_pct',
#        'dependent_midincome_pct', 'dependent_pct', 'fafsa_sent_2ormore_pct',
#        'fafsa_sent_3ormore_pct', 'fafsa_sent_4ormore_pct',
#        'fafsa_sent_5ormore_pct', 'faminc_independents_mean', 'faminc_mean',
#        'faminc_med', 'female_pct', 'fips', 'first_gen_student_pct',
#        'highincome1_pct', 'highincome2_pct', 'highincome_pct',
#        'independent_highincome1_pct', 'independent_highincome2_pct',
#        'independent_highincome_pct', 'independent_income_mean',
#        'independent_lowincome_pct', 'independent_midincome1_pct',
#        'independent_midincome2_pct', 'independent_midincome_pct',
#        'independent_pct', 'lowincome_pct', 'married_pct', 'midincome1_pct',
#        'midincome2_pct', 'midincome_pct', 'opeid', 'opeid6',
#        'parents_highest_ed_high_school', 'parents_highest_ed_middle_school',
#        'parents_highest_ed_postsecondary', 'unitid', 'veteran_pct', 'year'],
#       dtype='object')

# %%
sc_stud_char_columns = ['unitid', 'lowincome_pct', 'independent_pct', 
                        'dependent_lowincome_pct', 'independent_lowincome_pct', 
                        'midincome1_pct', 'midincome2_pct', 'highincome1_pct', 
                        'highincome2_pct', 'dependent_midincome1_pct', 
                        'dependent_midincome2_pct', 'dependent_highincome1_pct', 
                        'dependent_highincome2_pct', 'independent_midincome1_pct', 
                        'independent_midincome2_pct', 'independent_highincome1_pct', 
                        'independent_highincome2_pct', 'fafsa_sent_2ormore_pct', 
                        'fafsa_sent_3ormore_pct', 'fafsa_sent_4ormore_pct', 
                        'fafsa_sent_5ormore_pct', 'dependent_income_mean', 
                        'independent_income_mean', 'count_family_income', 
                        'count_family_income_dependent', 'count_family_income_independent', 
                        'count_valid_dep_status', 'count_parent_ed', 
                        'count_total_fafsa_applicants', 'female_pct', 'married_pct', 
                        'dependent_pct', 'veteran_pct', 'first_gen_student_pct', 
                        'faminc_mean', 'faminc_med', 'faminc_independents_mean', 
                        'midincome_pct', 'highincome_pct', 'dependent_midincome_pct', 
                        'dependent_highincome_pct', 'independent_midincome_pct', 
                        'independent_highincome_pct']
sc_stud_char = sc_stud_char_df[sc_stud_char_columns]

# Replace nan values with None
# Check if in directory
sc_stud_char = sc_stud_char.where((pd.notnull(sc_stud_char)), None)
sc_stud_char = sc_stud_char[sc_stud_char['unitid'].isin(ipeds_dir['unitid'])]

# %% [markdown]
# ## Insert into MySQL Table

# %%
sc_stud_char_tuple = data_to_tuples(sc_stud_char)
insert_data(sc_stud_char_tuple, 'sc_stud_char', sc_stud_char.columns)
# Out:
# INSERT INTO sc_stud_char (unitid, lowincome_pct, independent_pct, dependent_lowincome_pct, independent_lowincome_pct, midincome1_pct, midincome2_pct, highincome1_pct, highincome2_pct, dependent_midincome1_pct, dependent_midincome2_pct, dependent_highincome1_pct, dependent_highincome2_pct, independent_midincome1_pct, independent_midincome2_pct, independent_highincome1_pct, independent_highincome2_pct, fafsa_sent_2ormore_pct, fafsa_sent_3ormore_pct, fafsa_sent_4ormore_pct, fafsa_sent_5ormore_pct, dependent_income_mean, independent_income_mean, count_family_income, count_family_income_dependent, count_family_income_independent, count_valid_dep_status, count_parent_ed, count_total_fafsa_applicants, female_pct, married_pct, dependent_pct, veteran_pct, first_gen_student_pct, faminc_mean, faminc_med, faminc_independents_mean, midincome_pct, highincome_pct, dependent_midincome_pct, dependent_highincome_pct, independent_midincome_pct, independent_highincome_pct) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# 'inserted data'

# %% [markdown]
# # Get Enrollment Headcount

# %%
url = "https://educationdata.urban.org/api/v1/college-university/ipeds/enrollment-headcount/2016/1/"
ipeds_ug_headcount = get_educationdata(url)
ipeds_ug_headcount_df = pages_to_one_df(ipeds_ug_headcount)
# Out:
# expecting 194190 rows of data
# appended page 2
# appended page 3
# appended page 4
# appended page 5
# appended page 6
# appended page 7
# appended page 8
# appended page 9
# appended page 10
# appended page 11
# appended page 12
# appended page 13
# appended page 14
# appended page 15
# appended page 16
# appended page 17
# appended page 18
# appended page 19
# appended page 20
# appended page 21
# appended page 22
# appended page 23
# appended page 24
# appended page 25
# appended page 26
# appended page 27
# appended page 28
# appended page 29
# appended page 30
# appended page 31
# appended page 32
# appended page 33
# appended page 34
# appended page 35
# appended page 36
# appended page 37
# appended page 38
# appended page 39
# appended page 40
# appended page 41
# appended page 42
# appended page 43
# appended page 44
# appended page 45
# appended page 46
# appended page 47
# appended page 48
# appended page 49
# appended page 50
# appended page 51
# appended page 52
# appended page 53
# appended page 54
# appended page 55
# appended page 56
# appended page 57
# appended page 58
# appended page 59
# appended page 60
# appended page 61
# appended page 62
# appended page 63
# appended page 64
# appended page 65
# appended page 66
# appended page 67
# appended page 68
# appended page 69
# appended page 70
# appended page 71
# appended page 72
# appended page 73
# appended page 74
# appended page 75
# appended page 76
# appended page 77
# appended page 78
# appended page 79
# appended page 80
# appended page 81
# appended page 82
# appended page 83
# appended page 84
# appended page 85
# appended page 86
# appended page 87
# appended page 88
# appended page 89
# appended page 90
# appended page 91
# appended page 92
# appended page 93
# appended page 94
# appended page 95
# appended page 96
# appended page 97
# appended page 98
# appended page 99
# appended page 100
# appended page 101
# appended page 102
# appended page 103
# appended page 104
# appended page 105
# appended page 106
# appended page 107
# appended page 108
# appended page 109
# appended page 110
# appended page 111
# appended page 112
# appended page 113
# appended page 114
# appended page 115
# appended page 116
# appended page 117
# appended page 118
# appended page 119
# appended page 120
# appended page 121
# appended page 122
# appended page 123
# appended page 124
# appended page 125
# appended page 126
# appended page 127
# appended page 128
# appended page 129
# appended page 130
# appended page 131
# appended page 132
# appended page 133
# appended page 134
# appended page 135
# appended page 136
# appended page 137
# appended page 138
# appended page 139
# appended page 140
# appended page 141
# appended page 142
# appended page 143
# appended page 144
# appended page 145
# appended page 146
# appended page 147
# appended page 148
# appended page 149
# appended page 150
# appended page 151
# appended page 152
# appended page 153
# appended page 154
# appended page 155
# appended page 156
# appended page 157
# appended page 158
# appended page 159
# appended page 160
# appended page 161
# appended page 162
# appended page 163
# appended page 164
# appended page 165
# appended page 166
# appended page 167
# appended page 168
# appended page 169
# appended page 170
# appended page 171
# appended page 172
# appended page 173
# appended page 174
# appended page 175
# appended page 176
# appended page 177
# appended page 178
# appended page 179
# appended page 180
# appended page 181
# appended page 182
# appended page 183
# appended page 184
# appended page 185
# appended page 186
# appended page 187
# appended page 188
# appended page 189
# appended page 190
# appended page 191
# appended page 192
# appended page 193
# appended page 194
# appended page 195

# %%
ipeds_ug_headcount_df = ipeds_ug_headcount_df.drop(['fips', 'year'], axis = 1)

# %%
# Replace nan values with None
# Check if in directory
ipeds_ug_headcount_df = ipeds_ug_headcount_df.where((pd.notnull(ipeds_ug_headcount_df)), None)
ipeds_ug_headcount_df = ipeds_ug_headcount_df[ipeds_ug_headcount_df['unitid'].isin(ipeds_dir['unitid'])]

# %%
ipeds_ug_headcount_df.shape
# Out:
# (123060, 5)

# %%
ipeds_ug_headcount_df.replace({'sex': {1: 'M', 2: 'F', 9: 'U', 99: 'Total', 
                                       -1: 'missing', -2: 'NA', -3: 'suppressed'}, 
                               'race': {1: 'wht', 2: 'blk', 3: 'hsp', 4: 'asn', 
                                        5: 'ntv', 6: 'hwn/pi', 7: 'mlt', 8: 'nonres', 
                                        9: 'unknown', 20: 'other', 99: 'total', 
                                        -1: 'missing', -2: 'NA', -3: 'suppressed'}}, 
                              inplace = True)

# %%
ipeds_ug_headcount_piv = pd.pivot_table(ipeds_ug_headcount_df, index = 'unitid', columns = ['race', 'sex']).reset_index()

# %%
columns = ['_'.join(col).strip('_') for col in ipeds_ug_headcount_piv.columns.values]
ipeds_ug_headcount_piv.columns = columns

# %%
ipeds_ug_headcount_piv.head()
# Out:
#    unitid  headcount_asn_F  headcount_asn_M  headcount_asn_Total  \
# 0  100654                6                6                   12
# 1  100663              417              326                  743
# 2  100690                1                1                    2
# 3  100706              137              167                  304
# 4  100724                9                8                   17
#
#    headcount_blk_F  headcount_blk_M  headcount_blk_Total  headcount_hsp_F  \
# 0             2679             2063                 4742               18
# 1             2355             1142                 3497              243
# 2              139               56                  195               25
# 3              463              350                  813              143
# 4             3013             1854                 4867               30
#
#    headcount_hsp_M  headcount_hsp_Total  ...  level_of_study_ntv_Total  \
# 0               18                   36  ...                         1
# 1              186                  429  ...                         1
# 2               19                   44  ...                         1
# 3              170                  313  ...                         1
# 4               29                   59  ...                         1
#
#    level_of_study_total_F  level_of_study_total_M  level_of_study_total_Total  \
# 0                       1                       1                           1
# 1                       1                       1                           1
# 2                       1                       1                           1
# 3                       1                       1                           1
# 4                       1                       1                           1
#
#    level_of_study_unknown_F  level_of_study_unknown_M  \
# 0                         1                         1
# 1                         1                         1
# 2                         1                         1
# 3                         1                         1
# 4                         1                         1
#
#    level_of_study_unknown_Total  level_of_study_wht_F  level_of_study_wht_M  \
# 0                             1                     1                     1
# 1                             1                     1                     1
# 2                             1                     1                     1
# 3                             1                     1                     1
# 4                             1                     1                     1
#
#    level_of_study_wht_Total
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
#
# [5 rows x 61 columns]

# %%
ipeds_ug_headcount_piv.shape
# Out:
# (4102, 61)

# %%
ipeds_ug_headcount_piv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4102 entries, 0 to 4101
# Data columns (total 61 columns):
# unitid                          4102 non-null int64
# headcount_asn_F                 4102 non-null int64
# headcount_asn_M                 4102 non-null int64
# headcount_asn_Total             4102 non-null int64
# headcount_blk_F                 4102 non-null int64
# headcount_blk_M                 4102 non-null int64
# headcount_blk_Total             4102 non-null int64
# headcount_hsp_F                 4102 non-null int64
# headcount_hsp_M                 4102 non-null int64
# headcount_hsp_Total             4102 non-null int64
# headcount_hwn/pi_F              4102 non-null int64
# headcount_hwn/pi_M              4102 non-null int64
# headcount_hwn/pi_Total          4102 non-null int64
# headcount_mlt_F                 4102 non-null int64
# headcount_mlt_M                 4102 non-null int64
# headcount_mlt_Total             4102 non-null int64
# headcount_nonres_F              4102 non-null int64
# headcount_nonres_M              4102 non-null int64
# headcount_nonres_Total          4102 non-null int64
# headcount_ntv_F                 4102 non-null int64
# headcount_ntv_M                 4102 non-null int64
# headcount_ntv_Total             4102 non-null int64
# headcount_total_F               4102 non-null int64
# headcount_total_M               4102 non-null int64
# headcount_total_Total           4102 non-null int64
# headcount_unknown_F             4102 non-null int64
# headcount_unknown_M             4102 non-null int64
# headcount_unknown_Total         4102 non-null int64
# headcount_wht_F                 4102 non-null int64
# headcount_wht_M                 4102 non-null int64
# headcount_wht_Total             4102 non-null int64
# level_of_study_asn_F            4102 non-null int64
# level_of_study_asn_M            4102 non-null int64
# level_of_study_asn_Total        4102 non-null int64
# level_of_study_blk_F            4102 non-null int64
# level_of_study_blk_M            4102 non-null int64
# level_of_study_blk_Total        4102 non-null int64
# level_of_study_hsp_F            4102 non-null int64
# level_of_study_hsp_M            4102 non-null int64
# level_of_study_hsp_Total        4102 non-null int64
# level_of_study_hwn/pi_F         4102 non-null int64
# level_of_study_hwn/pi_M         4102 non-null int64
# level_of_study_hwn/pi_Total     4102 non-null int64
# level_of_study_mlt_F            4102 non-null int64
# level_of_study_mlt_M            4102 non-null int64
# level_of_study_mlt_Total        4102 non-null int64
# level_of_study_nonres_F         4102 non-null int64
# level_of_study_nonres_M         4102 non-null int64
# level_of_study_nonres_Total     4102 non-null int64
# level_of_study_ntv_F            4102 non-null int64
# level_of_study_ntv_M            4102 non-null int64
# level_of_study_ntv_Total        4102 non-null int64
# level_of_study_total_F          4102 non-null int64
# level_of_study_total_M          4102 non-null int64
# level_of_study_total_Total      4102 non-null int64
# level_of_study_unknown_F        4102 non-null int64
# level_of_study_unknown_M        4102 non-null int64
# level_of_study_unknown_Total    4102 non-null int64
# level_of_study_wht_F            4102 non-null int64
# level_of_study_wht_M            4102 non-null int64
# level_of_study_wht_Total        4102 non-null int64
# dtypes: int64(61)
# memory usage: 1.9 MB

# %%
# All level_of_study is 1 --> columns are irrelevant
pd.DataFrame(ipeds_ug_headcount_piv.describe()).iloc[:, 50:]
# Out:
#        level_of_study_ntv_M  level_of_study_ntv_Total  level_of_study_total_F  \
# count                4102.0                    4102.0                  4102.0
# mean                    1.0                       1.0                     1.0
# std                     0.0                       0.0                     0.0
# min                     1.0                       1.0                     1.0
# 25%                     1.0                       1.0                     1.0
# 50%                     1.0                       1.0                     1.0
# 75%                     1.0                       1.0                     1.0
# max                     1.0                       1.0                     1.0
#
#        level_of_study_total_M  level_of_study_total_Total  \
# count                  4102.0                      4102.0
# mean                      1.0                         1.0
# std                       0.0                         0.0
# min                       1.0                         1.0
# 25%                       1.0                         1.0
# 50%                       1.0                         1.0
# 75%                       1.0                         1.0
# max                       1.0                         1.0
#
#        level_of_study_unknown_F  level_of_study_unknown_M  \
# count                    4102.0                    4102.0
# mean                        1.0                       1.0
# std                         0.0                       0.0
# min                         1.0                       1.0
# 25%                         1.0                       1.0
# 50%                         1.0                       1.0
# 75%                         1.0                       1.0
# max                         1.0                       1.0
#
#        level_of_study_unknown_Total  level_of_study_wht_F  \
# count                        4102.0                4102.0
# mean                            1.0                   1.0
# std                             0.0                   0.0
# min                             1.0                   1.0
# 25%                             1.0                   1.0
# 50%                             1.0                   1.0
# 75%                             1.0                   1.0
# max                             1.0                   1.0
#
#        level_of_study_wht_M  level_of_study_wht_Total
# count                4102.0                    4102.0
# mean                    1.0                       1.0
# std                     0.0                       0.0
# min                     1.0                       1.0
# 25%                     1.0                       1.0
# 50%                     1.0                       1.0
# 75%                     1.0                       1.0
# max                     1.0                       1.0

# %%
cols = ['unitid'] + [x for x in ipeds_ug_headcount_piv.columns if 'headcount' in x]

# %%
cols
# Out:
# ['unitid',
#  'headcount_asn_F',
#  'headcount_asn_M',
#  'headcount_asn_Total',
#  'headcount_blk_F',
#  'headcount_blk_M',
#  'headcount_blk_Total',
#  'headcount_hsp_F',
#  'headcount_hsp_M',
#  'headcount_hsp_Total',
#  'headcount_hwn/pi_F',
#  'headcount_hwn/pi_M',
#  'headcount_hwn/pi_Total',
#  'headcount_mlt_F',
#  'headcount_mlt_M',
#  'headcount_mlt_Total',
#  'headcount_nonres_F',
#  'headcount_nonres_M',
#  'headcount_nonres_Total',
#  'headcount_ntv_F',
#  'headcount_ntv_M',
#  'headcount_ntv_Total',
#  'headcount_total_F',
#  'headcount_total_M',
#  'headcount_total_Total',
#  'headcount_unknown_F',
#  'headcount_unknown_M',
#  'headcount_unknown_Total',
#  'headcount_wht_F',
#  'headcount_wht_M',
#  'headcount_wht_Total']

# %%
ipeds_ug_headcount_sub = ipeds_ug_headcount_piv[cols]
ipeds_ug_headcount_sub.columns = [x.replace('/', '') for x in cols]

# %%
ipeds_ug_headcount_sub.head()
# Out:
#    unitid  headcount_asn_F  headcount_asn_M  headcount_asn_Total  \
# 0  100654                6                6                   12
# 1  100663              417              326                  743
# 2  100690                1                1                    2
# 3  100706              137              167                  304
# 4  100724                9                8                   17
#
#    headcount_blk_F  headcount_blk_M  headcount_blk_Total  headcount_hsp_F  \
# 0             2679             2063                 4742               18
# 1             2355             1142                 3497              243
# 2              139               56                  195               25
# 3              463              350                  813              143
# 4             3013             1854                 4867               30
#
#    headcount_hsp_M  headcount_hsp_Total  ...  headcount_ntv_Total  \
# 0               18                   36  ...                   11
# 1              186                  429  ...                   36
# 2               19                   44  ...                    0
# 3              170                  313  ...                   90
# 4               29                   59  ...                    8
#
#    headcount_total_F  headcount_total_M  headcount_total_Total  \
# 0               2921               2286                   5207
# 1               7780               5528                  13308
# 2                254                177                    431
# 3               3232               4287                   7519
# 4               3205               2024                   5229
#
#    headcount_unknown_F  headcount_unknown_M  headcount_unknown_Total  \
# 0                    7                    4                       11
# 1                  109                   89                      198
# 2                   59                   64                      123
# 3                  293                  302                      595
# 4                   29                   22                       51
#
#    headcount_wht_F  headcount_wht_M  headcount_wht_Total
# 0               55               82                  137
# 1             4188             3327                 7515
# 2               29               37                   66
# 3             2021             3034                 5055
# 4               41               42                   83
#
# [5 rows x 31 columns]

# %%
ipeds_ug_headcount_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4102 entries, 0 to 4101
# Data columns (total 31 columns):
# unitid                     4102 non-null int64
# headcount_asn_F            4102 non-null int64
# headcount_asn_M            4102 non-null int64
# headcount_asn_Total        4102 non-null int64
# headcount_blk_F            4102 non-null int64
# headcount_blk_M            4102 non-null int64
# headcount_blk_Total        4102 non-null int64
# headcount_hsp_F            4102 non-null int64
# headcount_hsp_M            4102 non-null int64
# headcount_hsp_Total        4102 non-null int64
# headcount_hwnpi_F          4102 non-null int64
# headcount_hwnpi_M          4102 non-null int64
# headcount_hwnpi_Total      4102 non-null int64
# headcount_mlt_F            4102 non-null int64
# headcount_mlt_M            4102 non-null int64
# headcount_mlt_Total        4102 non-null int64
# headcount_nonres_F         4102 non-null int64
# headcount_nonres_M         4102 non-null int64
# headcount_nonres_Total     4102 non-null int64
# headcount_ntv_F            4102 non-null int64
# headcount_ntv_M            4102 non-null int64
# headcount_ntv_Total        4102 non-null int64
# headcount_total_F          4102 non-null int64
# headcount_total_M          4102 non-null int64
# headcount_total_Total      4102 non-null int64
# headcount_unknown_F        4102 non-null int64
# headcount_unknown_M        4102 non-null int64
# headcount_unknown_Total    4102 non-null int64
# headcount_wht_F            4102 non-null int64
# headcount_wht_M            4102 non-null int64
# headcount_wht_Total        4102 non-null int64
# dtypes: int64(31)
# memory usage: 993.5 KB

# %% [markdown]
# ## Insert into MySQL

# %%
# For each value, convert to Python native int type (np int type not acceptable to MySQL)
ipeds_ug_headcount_tuple = []
for row in ipeds_ug_headcount_sub.values:
    row_lst = []
    for item in row:
        row_lst.append(item.item())
    ipeds_ug_headcount_tuple.append(tuple(row_lst))

# %%
ipeds_ug_headcount_tuple[0]
# Out:
# (100654,
#  6,
#  6,
#  12,
#  2679,
#  2063,
#  4742,
#  18,
#  18,
#  36,
#  5,
#  5,
#  10,
#  128,
#  82,
#  210,
#  15,
#  23,
#  38,
#  8,
#  3,
#  11,
#  2921,
#  2286,
#  5207,
#  7,
#  4,
#  11,
#  55,
#  82,
#  137)

# %%
# ipeds_ug_headcount_tuple = data_to_tuples(ipeds_ug_headcount_sub)
insert_data(ipeds_ug_headcount_tuple, 'ipeds_ug_headcount', ipeds_ug_headcount_sub.columns)
# Out:
# INSERT INTO ipeds_ug_headcount (unitid, headcount_asn_F, headcount_asn_M, headcount_asn_Total, headcount_blk_F, headcount_blk_M, headcount_blk_Total, headcount_hsp_F, headcount_hsp_M, headcount_hsp_Total, headcount_hwnpi_F, headcount_hwnpi_M, headcount_hwnpi_Total, headcount_mlt_F, headcount_mlt_M, headcount_mlt_Total, headcount_nonres_F, headcount_nonres_M, headcount_nonres_Total, headcount_ntv_F, headcount_ntv_M, headcount_ntv_Total, headcount_total_F, headcount_total_M, headcount_total_Total, headcount_unknown_F, headcount_unknown_M, headcount_unknown_Total, headcount_wht_F, headcount_wht_M, headcount_wht_Total) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# 'inserted data'

# %% [markdown]
# # Get Graduation Rate Info Based on Financial Aid

# %%
url = "https://educationdata.urban.org/api/v1/college-university/ipeds/grad-rates-pell/2016/"
ipeds_grad_fa = get_educationdata(url)
ipeds_grad_fa_df = pages_to_one_df(ipeds_grad_fa)
# Out:
# expecting 43228 rows of data
# appended page 2
# appended page 3
# appended page 4
# appended page 5
# appended page 6
# appended page 7
# appended page 8
# appended page 9
# appended page 10
# appended page 11
# appended page 12
# appended page 13
# appended page 14
# appended page 15
# appended page 16
# appended page 17
# appended page 18
# appended page 19
# appended page 20
# appended page 21
# appended page 22
# appended page 23
# appended page 24
# appended page 25
# appended page 26
# appended page 27
# appended page 28
# appended page 29
# appended page 30
# appended page 31
# appended page 32
# appended page 33
# appended page 34
# appended page 35
# appended page 36
# appended page 37
# appended page 38
# appended page 39
# appended page 40
# appended page 41
# appended page 42
# appended page 43
# appended page 44

# %%
ipeds_grad_fa_df.head()
# Out:
#    cohort_adj  cohort_rev  cohort_year  completers_150pct  \
# 0          24          24         2011                 12
# 1           4           4         2011                  0
# 2         137         137         2014                100
# 3           8           8         2014                  8
# 4         139         139         2011                 40
#
#    completion_rate_150pct  exclusions  fed_aid_type  fips  institution_level  \
# 0                   0.500           0            99    17                  4
# 1                   0.000           0             3    27                  4
# 2                   0.730           0             1     6                  1
# 3                   1.000           0            99     9                  3
# 4                   0.288           0             3    42                  4
#
#    subcohort  unitid  year
# 0          2  147536  2016
# 1         99  440767  2016
# 2         99  119553  2016
# 3         99  417178  2016
# 4         99  215275  2016

# %%
ipeds_grad_fa_df.describe()
# Out:
#          cohort_adj    cohort_rev   cohort_year  completers_150pct  \
# count  43228.000000  43228.000000  43228.000000       43228.000000
# mean     219.185435    220.044740   2012.457389         115.157444
# std      696.282169    699.116868      1.499412         350.848093
# min        0.000000      0.000000   2011.000000           0.000000
# 25%        7.000000      7.000000   2011.000000           3.000000
# 50%       44.000000     44.000000   2011.000000          22.000000
# 75%      187.000000    187.000000   2014.000000          89.000000
# max    50695.000000  50789.000000   2014.000000       13600.000000
#
#        completion_rate_150pct    exclusions  fed_aid_type          fips  \
# count            39301.000000  43228.000000   43228.00000  43228.000000
# mean                 0.543069      0.859304      26.25000     29.774591
# std                  0.277793     21.439059      42.00867     16.796727
# min                  0.000000      0.000000       1.00000      1.000000
# 25%                  0.333000      0.000000       1.75000     15.000000
# 50%                  0.553000      0.000000       2.50000     31.000000
# 75%                  0.750000      0.000000      27.00000     42.000000
# max                  1.000000   2131.000000      99.00000     78.000000
#
#        institution_level     subcohort         unitid     year
# count       43228.000000  43228.000000   43228.000000  43228.0
# mean            3.201258     70.497085  276042.314518   2016.0
# std             1.048625     44.291262  132209.978858      0.0
# min             1.000000      1.000000  100654.000000   2016.0
# 25%             3.000000      2.000000  168342.000000   2016.0
# 50%             4.000000     99.000000  217624.000000   2016.0
# 75%             4.000000     99.000000  438285.000000   2016.0
# max             4.000000     99.000000  491242.000000   2016.0

# %%
# Replace numerical sex var with string representation
ipeds_grad_fa_df = ipeds_grad_fa_df.drop(['fips', 'year'], axis = 1)
ipeds_grad_fa_df = ipeds_grad_fa_df.replace({'subcohort': {1: 'nonbach', 2: 'bach', 99: 'total'}})
ipeds_grad_fa_df = ipeds_grad_fa_df.replace({'fed_aid_type': {1: 'pell', 2: 'stafford', 3: 'neither', 4: 'not_pell', 99: 'total'}})

ipeds_grad_fa_df.head()
# Out:
#    cohort_adj  cohort_rev  cohort_year  completers_150pct  \
# 0          24          24         2011                 12
# 1           4           4         2011                  0
# 2         137         137         2014                100
# 3           8           8         2014                  8
# 4         139         139         2011                 40
#
#    completion_rate_150pct  exclusions fed_aid_type  institution_level  \
# 0                   0.500           0        total                  4
# 1                   0.000           0      neither                  4
# 2                   0.730           0         pell                  1
# 3                   1.000           0        total                  3
# 4                   0.288           0      neither                  4
#
#   subcohort  unitid
# 0      bach  147536
# 1     total  440767
# 2     total  119553
# 3     total  417178
# 4     total  215275

# %% [markdown]
# ## Get Data for Bachelor's Degrees

# %%
# Subset for bachelor's degrees, pivot table
ipeds_grad_fa_bach = ipeds_grad_fa_df[ipeds_grad_fa_df['subcohort'] == 'bach']
ipeds_grad_fa_bach = ipeds_grad_fa_bach.pivot(index = 'unitid', columns = 'fed_aid_type')
ipeds_grad_fa_bach.reset_index(inplace = True)
ipeds_grad_fa_bach.columns = ['_'.join(col).strip('_') for col in ipeds_grad_fa_bach.columns.values]

# %%
# Replace nan values with None
# Check if in directory
ipeds_grad_fa_bach = ipeds_grad_fa_bach.where((pd.notnull(ipeds_grad_fa_bach)), None)
ipeds_grad_fa_bach = ipeds_grad_fa_bach[ipeds_grad_fa_bach['unitid'].isin(ipeds_dir['unitid'])]

# %%
ipeds_grad_fa_bach.head()
# Out:
#    unitid  cohort_adj_neither  cohort_adj_pell  cohort_adj_stafford  \
# 0  100654                  60              667                  112
# 1  100663                 794              582                  200
# 2  100690                   9                0                    0
# 3  100706                 316              205                  131
# 4  100724                 143              891                   64
#
#    cohort_adj_total  cohort_rev_neither  cohort_rev_pell  cohort_rev_stafford  \
# 0               839                  60              667                  112
# 1              1576                 795              582                  201
# 2                 9                   9                0                    0
# 3               652                 316              205                  131
# 4              1098                 143              891                   64
#
#    cohort_rev_total  cohort_year_neither  ...  exclusions_stafford  \
# 0               839                 2011  ...                    0
# 1              1578                 2011  ...                    1
# 2                 9                 2011  ...                    0
# 3               652                 2011  ...                    0
# 4              1098                 2011  ...                    0
#
#    exclusions_total  institution_level_neither  institution_level_pell  \
# 0                 0                          4                       4
# 1                 2                          4                       4
# 2                 0                          4                       4
# 3                 0                          4                       4
# 4                 0                          4                       4
#
#    institution_level_stafford  institution_level_total  subcohort_neither  \
# 0                           4                        4               bach
# 1                           4                        4               bach
# 2                           4                        4               bach
# 3                           4                        4               bach
# 4                           4                        4               bach
#
#   subcohort_pell subcohort_stafford subcohort_total
# 0           bach               bach            bach
# 1           bach               bach            bach
# 2           bach               bach            bach
# 3           bach               bach            bach
# 4           bach               bach            bach
#
# [5 rows x 33 columns]

# %%
ipeds_grad_fa_bach.shape
# Out:
# (2133, 33)

# %% [markdown]
# ## Get Data for Nonbachelor's Degrees

# %%
# Subset for nonbachelor's degrees, pivot table
ipeds_grad_fa_nonbach = ipeds_grad_fa_df[ipeds_grad_fa_df['subcohort'] == 'nonbach']
ipeds_grad_fa_nonbach = ipeds_grad_fa_nonbach.pivot(index = 'unitid', columns = 'fed_aid_type')
ipeds_grad_fa_nonbach.reset_index(inplace = True)
ipeds_grad_fa_nonbach.columns = ['_'.join(col).strip('_') for col in ipeds_grad_fa_nonbach.columns.values]

# %%
# Replace nan values with None
# Check if in directory
ipeds_grad_fa_nonbach = ipeds_grad_fa_nonbach.where((pd.notnull(ipeds_grad_fa_nonbach)), None)
ipeds_grad_fa_nonbach = ipeds_grad_fa_nonbach[ipeds_grad_fa_nonbach['unitid'].isin(ipeds_dir['unitid'])]

# %%
ipeds_grad_fa_nonbach.head()
# Out:
#    unitid  cohort_adj_neither  cohort_adj_pell  cohort_adj_stafford  \
# 0  100690                   2                0                    0
# 1  101073                   4                5                    1
# 2  101116                   7               16                    3
# 3  101365                   2               17                    2
# 4  101453                   0                1                    0
#
#    cohort_adj_total  cohort_rev_neither  cohort_rev_pell  cohort_rev_stafford  \
# 0                 2                   2                0                    0
# 1                10                   4                5                    1
# 2                26                   7               16                    3
# 3                21                   2               17                    2
# 4                 1                   0                1                    0
#
#    cohort_rev_total  cohort_year_neither  ...  exclusions_stafford  \
# 0                 2                 2011  ...                    0
# 1                10                 2011  ...                    0
# 2                26                 2011  ...                    0
# 3                21                 2011  ...                    0
# 4                 1                 2011  ...                    0
#
#    exclusions_total  institution_level_neither  institution_level_pell  \
# 0                 0                          4                       4
# 1                 0                          4                       4
# 2                 0                          4                       4
# 3                 0                          4                       4
# 4                 0                          4                       4
#
#    institution_level_stafford  institution_level_total  subcohort_neither  \
# 0                           4                        4            nonbach
# 1                           4                        4            nonbach
# 2                           4                        4            nonbach
# 3                           4                        4            nonbach
# 4                           4                        4            nonbach
#
#   subcohort_pell subcohort_stafford subcohort_total
# 0        nonbach            nonbach         nonbach
# 1        nonbach            nonbach         nonbach
# 2        nonbach            nonbach         nonbach
# 3        nonbach            nonbach         nonbach
# 4        nonbach            nonbach         nonbach
#
# [5 rows x 33 columns]

# %%
ipeds_grad_fa_nonbach.shape
# Out:
# (1025, 33)

# %% [markdown]
# ## Get Data for Total

# %%
# Subset for total, pivot table
ipeds_grad_fa_total = ipeds_grad_fa_df[ipeds_grad_fa_df['subcohort'] == 'total']
ipeds_grad_fa_total = ipeds_grad_fa_total.pivot(index = 'unitid', columns = ['fed_aid_type'])
#ipeds_grad_fa_total.reset_index(inplace = True)
#ipeds_grad_fa_total.columns = ['_'.join(col).strip('_') for col in ipeds_grad_fa_total.columns.values]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-11ad62775bae> in <module>
#       1 # Subset for total, pivot table
#       2 ipeds_grad_fa_total = ipeds_grad_fa_df[ipeds_grad_fa_df['subcohort'] == 'total']
# ----> 3 ipeds_grad_fa_total = ipeds_grad_fa_total.pivot(index = 'unitid', columns = ['fed_aid_type'])
#       4 #ipeds_grad_fa_total.reset_index(inplace = True)
#       5 #ipeds_grad_fa_total.columns = ['_'.join(col).strip('_') for col in ipeds_grad_fa_total.columns.values]
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5626     def pivot(self, index=None, columns=None, values=None):
#    5627         from pandas.core.reshape.pivot import pivot
# -> 5628         return pivot(self, index=index, columns=columns, values=values)
#    5629
#    5630     _shared_docs['pivot_table'] = """
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     371         cols = [columns] if index is None else [index, columns]
#     372         append = index is None
# --> 373         indexed = data.set_index(cols, append=append)
#     374     else:
#     375         if index is None:
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4182             arrays.append(level)
#    4183
# -> 4184         index = ensure_index_from_sequences(arrays, names)
#    4185
#    4186         if verify_integrity and not index.is_unique:
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in ensure_index_from_sequences(sequences, names)
#    5313         return Index(sequences[0], name=names)
#    5314     else:
# -> 5315         return MultiIndex.from_arrays(sequences, names=names)
#    5316
#    5317
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in from_arrays(cls, arrays, sortorder, names)
#     334         for i in range(1, len(arrays)):
#     335             if len(arrays[i]) != len(arrays[i - 1]):
# --> 336                 raise ValueError('all arrays must be same length')
#     337
#     338         from pandas.core.arrays.categorical import _factorize_from_iterables
#
# ValueError: all arrays must be same length

# %%
ipeds_dup = ipeds_grad_fa_total[ipeds_grad_fa_total.duplicated(subset = 'unitid')]
